# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

# %% [markdown]
# # Episode Transcripts

# %% [markdown]
# ## 1. Rebirth

# %%
# Get the url
rebirth='https://deathnote.fandom.com/wiki/Rebirth/Transcript'
page=requests.get(rebirth)
page.encoding='utf-8'
# Beautify
soup=BeautifulSoup(page.text, 'html')

# Extract the column with the characters' names
actor =soup.find_all('th')
characters=[character.text.strip() for character in actor]

# Extract their dialogue
speech=soup.find_all('td')
dialogue=[dialog.text.strip() for dialog in speech]

# Assign the data in two different data frames
characters = pd.DataFrame({'Characters': characters})
dialogue = pd.DataFrame({'Dialogue': dialogue})

# Drop the first 2 rows in the dialogue data frame as they are irrelevant

dialogue=dialogue.drop([0,1]).reset_index(drop=True)

# Identify the indices of blank rows. These blsnk rows represent the narrators' character 
blank_indices = dialogue[dialogue['Dialogue'].str.strip() == ''].index
blank_indices
# Create a list of indices to drop (blank rows and the ones immediately after) We are dropping the rows after the blank rows as those represent
#the narrators dialogue

drop_indices = set(blank_indices)
drop_indices.update(blank_indices + 1)

# Drop the rows with these indices
dialogue = dialogue.drop(index=drop_indices)
dialogue = dialogue.reset_index(drop=True)

# Ensure both DataFrames have the same number of rows
if len(characters) != len(dialogue):
    raise ValueError("Both DataFrames must have the same number of rows")

# Insert the column from df2 into df1 at the second position
rebirth=characters.insert(1, 'Dialogue', dialogue['Dialogue'])

# Insert a column from of the Eoisode name at the beginning
characters.insert(0, 'Episode Name', 'Rebirth')
rebirth=characters
print(rebirth.head(1))
rebirth.tail(1)
# Out:
#   Episode Name Characters                          Dialogue
# 0      Rebirth       Gook  What. A pair of sleeping skulls?
#     Episode Name Characters                                           Dialogue
# 120      Rebirth      Light  [Laughs] I'll show the world what happens when...

# %% [markdown]
# # Repeat for all episodes

# %% [markdown]
# ## 2. Confrontation

# %%
# Get the url
confrontation='https://deathnote.fandom.com/wiki/Confrontation/Transcript'
page=requests.get(confrontation)
page.encoding='utf-8'
# Beautify
soup=BeautifulSoup(page.text, 'html')

# Extract the column with the characters' names
actor =soup.find_all('th')
characters=[character.text.strip() for character in actor]

# Extract their dialogue
speech=soup.find_all('td')
dialogue=[dialog.text.strip() for dialog in speech]

# Assign the data in two different data frames
characters = pd.DataFrame({'Characters': characters})
dialogue = pd.DataFrame({'Dialogue': dialogue})

# Drop the first 2 rows in the dialogue data frame as they are irrelevant

dialogue=dialogue.drop([0,1]).reset_index(drop=True)

# Identify the indices of blank rows. These blsnk rows represent the narrators' character 
blank_indices = dialogue[dialogue['Dialogue'].str.strip() == ''].index
blank_indices
# Create a list of indices to drop (blank rows and the ones immediately after) We are dropping the rows after the blank rows as those represent
#the narrators dialogue

drop_indices = set(blank_indices)
drop_indices.update(blank_indices + 1)

# Drop the rows with these indices
dialogue = dialogue.drop(index=drop_indices)
dialogue = dialogue.reset_index(drop=True)

# Ensure both DataFrames have the same number of rows
if len(characters) != len(dialogue):
    raise ValueError("Both DataFrames must have the same number of rows")

# Insert the column from df2 into df1 at the second position
characters.insert(1, 'Dialogue', dialogue['Dialogue'])

# Insert a column from of the Eoisode name at the beginning
characters.insert(0, 'Episode Name', 'Confrontation')
confrontation=characters
print(confrontation.head(1))
confrontation.tail(1)
# Out:
#     Episode Name Characters                                           Dialogue
# 0  Confrontation      Light  The human whose name is written in this notebo...
#       Episode Name Characters  \
# 216  Confrontation      Light
#
#                                               Dialogue
# 216  I'm not the one who's going to find L. I can l...

# %% [markdown]
# ## 3. Dealings

# %%
# Get the url
dealings='https://deathnote.fandom.com/wiki/Dealings/Transcript'
page=requests.get(dealings)
page.encoding='utf-8'
# Beautify
soup=BeautifulSoup(page.text, 'html')

# Extract the column with the characters' names
actor =soup.find_all('th')
characters=[character.text.strip() for character in actor]

# Extract their dialogue
speech=soup.find_all('td')
dialogue=[dialog.text.strip() for dialog in speech]

# Assign the data in two different data frames
characters = pd.DataFrame({'Characters': characters})
dialogue = pd.DataFrame({'Dialogue': dialogue})

# Drop the first 2 rows in the dialogue data frame as they are irrelevant

dialogue=dialogue.drop([0,1]).reset_index(drop=True)

# Identify the indices of blank rows. These blsnk rows represent the narrators' character 
blank_indices = dialogue[dialogue['Dialogue'].str.strip() == ''].index
blank_indices
# Create a list of indices to drop (blank rows and the ones immediately after) We are dropping the rows after the blank rows as those represent
#the narrators dialogue

drop_indices = set(blank_indices)
drop_indices.update(blank_indices + 1)

# Drop the rows with these indices
dialogue = dialogue.drop(index=drop_indices)
dialogue = dialogue.reset_index(drop=True)

# Ensure both DataFrames have the same number of rows
if len(characters) != len(dialogue):
    raise ValueError("Both DataFrames must have the same number of rows")

# Insert the column from df2 into df1 at the second position
characters.insert(1, 'Dialogue', dialogue['Dialogue'])

# Insert a column from of the Eoisode name at the beginning
characters.insert(0, 'Episode Name', 'Dealings')
dealings=characters
print(dealings.head(1))
dealings.tail(1)
# Out:
#   Episode Name Characters                                           Dialogue
# 0     Dealings          L  Greetings to all of you at the ICPO. I…am L. W...
#     Episode Name Characters                                           Dialogue
# 159     Dealings      Light  Everything has turned out exactly as I wrote i...

# %% [markdown]
# ## 4. Pursuit

# %%
# Get the url
pursuit='https://deathnote.fandom.com/wiki/Pursuit/Transcript'
page=requests.get(pursuit)
page.encoding='utf-8'
# Beautify
soup=BeautifulSoup(page.text, 'html')

# Extract the column with the characters' names
actor =soup.find_all('th')
characters=[character.text.strip() for character in actor]

# Extract their dialogue
speech=soup.find_all('td')
dialogue=[dialog.text.strip() for dialog in speech]

# Assign the data in two different data frames
characters = pd.DataFrame({'Characters': characters})
dialogue = pd.DataFrame({'Dialogue': dialogue})

# Drop the first 2 rows in the dialogue data frame as they are irrelevant

dialogue=dialogue.drop([0,1]).reset_index(drop=True)

# Identify the indices of blank rows. These blsnk rows represent the narrators' character 
blank_indices = dialogue[dialogue['Dialogue'].str.strip() == ''].index
blank_indices
# Create a list of indices to drop (blank rows and the ones immediately after) We are dropping the rows after the blank rows as those represent
#the narrators dialogue

drop_indices = set(blank_indices)
drop_indices.update(blank_indices + 1)

# Drop the rows with these indices
dialogue = dialogue.drop(index=drop_indices)
dialogue = dialogue.reset_index(drop=True)

# Ensure both DataFrames have the same number of rows
if len(characters) != len(dialogue):
    raise ValueError("Both DataFrames must have the same number of rows")

# Insert the column from df2 into df1 at the second position
characters.insert(1, 'Dialogue', dialogue['Dialogue'])

# Insert a column from of the Eoisode name at the beginning
characters.insert(0, 'Episode Name', 'Pursuit')
pursuit=characters
print(pursuit.head(1))
pursuit.tail(1)
# Out:
#   Episode Name Characters                                           Dialogue
# 0      Pursuit   Soichiro  [V.O.] What? I don't believe this. Another twe...
#     Episode Name Characters                                           Dialogue
# 154      Pursuit      Light  [V.O.] It's just as I thought. He doesn't susp...

# %% [markdown]
# ## 5. Tactics

# %%
# Get the url
tactics='https://deathnote.fandom.com/wiki/Tactics/Transcript'
page=requests.get(tactics)
page.encoding='utf-8'
# Beautify
soup=BeautifulSoup(page.text, 'html')

# Extract the column with the characters' names
actor =soup.find_all('th')
characters=[character.text.strip() for character in actor]

# Extract their dialogue
speech=soup.find_all('td')
dialogue=[dialog.text.strip() for dialog in speech]

# Assign the data in two different data frames
characters = pd.DataFrame({'Characters': characters})
dialogue = pd.DataFrame({'Dialogue': dialogue})

# Drop the first 2 rows in the dialogue data frame as they are irrelevant

dialogue=dialogue.drop([0,1]).reset_index(drop=True)

# Identify the indices of blank rows. These blsnk rows represent the narrators' character 
blank_indices = dialogue[dialogue['Dialogue'].str.strip() == ''].index
blank_indices
# Create a list of indices to drop (blank rows and the ones immediately after) We are dropping the rows after the blank rows as those represent
#the narrators dialogue

drop_indices = set(blank_indices)
drop_indices.update(blank_indices + 1)

# Drop the rows with these indices
dialogue = dialogue.drop(index=drop_indices)
dialogue = dialogue.reset_index(drop=True)

# Ensure both DataFrames have the same number of rows
if len(characters) != len(dialogue):
    raise ValueError("Both DataFrames must have the same number of rows")

# Insert the column from df2 into df1 at the second position
characters.insert(1, 'Dialogue', dialogue['Dialogue'])

# Insert a column from of the Eoisode name at the beginning
characters.insert(0, 'Episode Name', 'Tactics')
tactics=characters
print(tactics.head(1))
tactics.tail(1)
# Out:
#   Episode Name Characters    Dialogue
# 0      Tactics       Raye  You there.
#     Episode Name Characters                                           Dialogue
# 146      Tactics      Light  This woman. If she had spoken to the police be...

# %% [markdown]
# ## 6. Unraveling

# %%
# Get the url
unraveling='https://deathnote.fandom.com/wiki/Unraveling/Transcript'
page=requests.get(unraveling)
page.encoding='utf-8'
# Beautify
soup=BeautifulSoup(page.text, 'html')

# Extract the column with the characters' names
actor =soup.find_all('th')
characters=[character.text.strip() for character in actor]

# Extract their dialogue
speech=soup.find_all('td')
dialogue=[dialog.text.strip() for dialog in speech]

# Assign the data in two different data frames
characters = pd.DataFrame({'Characters': characters})
dialogue = pd.DataFrame({'Dialogue': dialogue})

# Drop the first 2 rows in the dialogue data frame as they are irrelevant

dialogue=dialogue.drop([0,1]).reset_index(drop=True)

# Identify the indices of blank rows. These blsnk rows represent the narrators' character 
blank_indices = dialogue[dialogue['Dialogue'].str.strip() == ''].index
blank_indices
# Create a list of indices to drop (blank rows and the ones immediately after) We are dropping the rows after the blank rows as those represent
#the narrators dialogue

drop_indices = set(blank_indices)
drop_indices.update(blank_indices + 1)

# Drop the rows with these indices
dialogue = dialogue.drop(index=drop_indices)
dialogue = dialogue.reset_index(drop=True)

# Ensure both DataFrames have the same number of rows
if len(characters) != len(dialogue):
    raise ValueError("Both DataFrames must have the same number of rows")

# Insert the column from df2 into df1 at the second position
characters.insert(1, 'Dialogue', dialogue['Dialogue'])

# Insert a column from of the Eoisode name at the beginning
characters.insert(0, 'Episode Name', 'Unraveling')
unraveling=characters
print(unraveling.head(1))
unraveling.tail(1)
# Out:
#   Episode Name Characters            Dialogue
# 0   Unraveling          L  [monotone] I am L.
#     Episode Name Characters                                           Dialogue
# 167   Unraveling      Light  I have to admit, I'd really love to see how sh...

# %% [markdown]
# ## 7. Overcast

# %%
# Get the url

overcast='https://deathnote.fandom.com/wiki/Overcast/Transcript'
page=requests.get(overcast)
page.encoding='utf-8'

# Beautify

soup=BeautifulSoup(page.text, 'html')

# Extract the column with the characters' names

actor =soup.find_all('th')
characters=[character.text.strip() for character in actor]

# Extract their dialogue

speech=soup.find_all('td')
dialogue=[dialog.text.strip() for dialog in speech]

# Assign the data in two different data frames

characters = pd.DataFrame({'Characters': characters})
dialogue = pd.DataFrame({'Dialogue': dialogue})

# Drop the first 2 rows in the dialogue data frame as they are irrelevant

dialogue=dialogue.drop(range(8)).reset_index(drop=True)

# Fixing the issue with dialogue.iloc[66] Matsuda, a character has been placed in the wrong data frame

# Create a new DataFrame for the extra row

new_row = pd.DataFrame({'Characters': ['Matsuda']})
characters_part1 = characters.iloc[:66]
characters_part2 = characters.iloc[66:]
characters = pd.concat([characters_part1, new_row, characters_part2]).reset_index(drop=True)
dialogue = dialogue.drop(66).reset_index(drop=True)

# Identify the indices of blank rows. These blsnk rows represent the narrators' character 

blank_indices = dialogue[dialogue['Dialogue'].str.strip() == ''].index
blank_indices

# Create a list of indices to drop (blank rows and the ones immediately after) We are dropping the rows after the blank rows as those represent
#the narrators dialogue

drop_indices = set(blank_indices)
drop_indices.update(blank_indices + 1)

# Drop the rows with these indices

dialogue = dialogue.drop(index=drop_indices)
dialogue = dialogue.reset_index(drop=True)

# Ensure both DataFrames have the same number of rows

if len(characters) != len(dialogue):
    raise ValueError("Both DataFrames must have the same number of rows")

# Insert the column from df2 into df1 at the second position

characters.insert(1, 'Dialogue', dialogue['Dialogue'])

# Insert a column from of the Eoisode name at the beginning

characters.insert(0, 'Episode Name', 'Overcast')
overcast=characters
print(overcast.head(1))
overcast.tail(1)
# Out:
#   Episode Name Characters                                           Dialogue
# 0     Overcast      Light  [thinking] Regardless of how she came to the c...
#     Episode Name Characters                                           Dialogue
# 157     Overcast      Light  With Ryuk's information and my preparations, I...

# %% [markdown]
# ## 8. Glare

# %%
# Get the url
glare='https://deathnote.fandom.com/wiki/Glare/Transcript'
page=requests.get(glare)
page.encoding='utf-8'
# Beautify
soup=BeautifulSoup(page.text, 'html')

# Extract the column with the characters' names
actor =soup.find_all('th')
characters=[character.text.strip() for character in actor]

# Extract their dialogue
speech=soup.find_all('td')
dialogue=[dialog.text.strip() for dialog in speech]

# Assign the data in two different data frames
characters = pd.DataFrame({'Characters': characters})
dialogue = pd.DataFrame({'Dialogue': dialogue})

# Drop the first 2 rows in the dialogue data frame as they are irrelevant

dialogue=dialogue.drop([0,1]).reset_index(drop=True)

# Identify the indices of blank rows. These blsnk rows represent the narrators' character 
blank_indices = dialogue[dialogue['Dialogue'].str.strip() == ''].index
blank_indices
# Create a list of indices to drop (blank rows and the ones immediately after) We are dropping the rows after the blank rows as those represent
#the narrators dialogue

drop_indices = set(blank_indices)
drop_indices.update(blank_indices + 1)

# Drop the rows with these indices
dialogue = dialogue.drop(index=drop_indices)
dialogue = dialogue.reset_index(drop=True)

# Ensure both DataFrames have the same number of rows
if len(characters) != len(dialogue):
    raise ValueError("Both DataFrames must have the same number of rows")

# Insert the column from df2 into df1 at the second position
characters.insert(1, 'Dialogue', dialogue['Dialogue'])

# Insert a column from of the Eoisode name at the beginning
characters.insert(0, 'Episode Name', 'Glare')
glare=characters
print(glare.head(1))
glare.tail(1)
# Out:
#   Episode Name Characters                                           Dialogue
# 0        Glare     Aizawa  That was footage from surveillance cameras at ...
#     Episode Name Characters                                           Dialogue
# 174        Glare      Light  [chuckles] Perfect. There's no need for me to ...
